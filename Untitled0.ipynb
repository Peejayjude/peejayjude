# %% [markdown]
# <a href="https://colab.research.google.com/github/Peejayjude/peejayjude/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Peejay list
#
#
# 1.   List
# 2.   List item
#
# ---
# A | B | C
# --- |---| ---
# 2 | 3 | f
# 2 | 3 | r
#
# [School website](https://www.nstu.ru/)
#
# ![image.png](data:image/png;base64,...)
#
#
# ![Nstu-1.jpg](data:image/jpeg;base64,...)
